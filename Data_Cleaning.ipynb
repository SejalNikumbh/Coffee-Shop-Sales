# %% [markdown]
# <a href="https://colab.research.google.com/github/SejalNikumbh/Coffee-Shop-Sales/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/content/customer_blinkit.csv")
df=pd.DataFrame(data)
df
# Out:
#      CustomerID             Name       Phone                  Address  \
# 0             1      Kavya Reddy  9193214172       Koramangala, Delhi
# 1             2  Siddharth Joshi  1628503012      Civil Lines, Jaipur
# 2             3       Neha Joshi  6430427670   Civil Lines, Hyderabad
# 3             4  Siddharth Mehta  2645852001          MG Road, Jaipur
# 4             5     Rajesh Reddy  2428071930        Koramangala, Pune
# ..          ...              ...         ...                      ...
# 295         296     Rohit Sharma  6671028571    Gachibowli, Bangalore
# 296         297  Siddharth Joshi  6721377969      Malviya Nagar, Pune
# 297         298     Aarav Sharma  6633244842  Andheri West, Ahmedabad
# 298         299      Pooja Gupta  8413555089       Civil Lines, Delhi
# 299         300    Rajesh Sharma   640341465           MG Road, Delhi
#
#           City
# 0       Mumbai
# 1         Pune
# 2       Jaipur
# 3       Jaipur
# 4    Ahmedabad
# ..         ...
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# CustomerID    0
# Name          0
# Phone         0
# Address       0
# City          0
# dtype: int64
#      CustomerID             Name       Phone                  Address  \
# 0             1      Kavya Reddy  9193214172       Koramangala, Delhi
# 1             2  Siddharth Joshi  1628503012      Civil Lines, Jaipur
# 2             3       Neha Joshi  6430427670   Civil Lines, Hyderabad
# 3             4  Siddharth Mehta  2645852001          MG Road, Jaipur
# 4             5     Rajesh Reddy  2428071930        Koramangala, Pune
# ..          ...              ...         ...                      ...
# 295         296     Rohit Sharma  6671028571    Gachibowli, Bangalore
# 296         297  Siddharth Joshi  6721377969      Malviya Nagar, Pune
# 297         298     Aarav Sharma  6633244842  Andheri West, Ahmedabad
# 298         299      Pooja Gupta  8413555089       Civil Lines, Delhi
# 299         300    Rajesh Sharma   640341465           MG Road, Delhi
#
#           City
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      CustomerID             Name       Phone                  Address  \
# 0             1      Kavya Reddy  9193214172       Koramangala, Delhi
# 1             2  Siddharth Joshi  1628503012      Civil Lines, Jaipur
# 2             3       Neha Joshi  6430427670   Civil Lines, Hyderabad
# 3             4  Siddharth Mehta  2645852001          MG Road, Jaipur
# 4             5     Rajesh Reddy  2428071930        Koramangala, Pune
# ..          ...              ...         ...                      ...
# 295         296     Rohit Sharma  6671028571    Gachibowli, Bangalore
# 296         297  Siddharth Joshi  6721377969      Malviya Nagar, Pune
# 297         298     Aarav Sharma  6633244842  Andheri West, Ahmedabad
# 298         299      Pooja Gupta  8413555089       Civil Lines, Delhi
# 299         300    Rajesh Sharma   640341465           MG Road, Delhi
#
#           City
# 0       Mumbai
# 1         Pune
# 2       Jaipur
# 3       Jaipur
# 4    Ahmedabad
# ..         ...
# ...

# %%
# df["Last_Name"]=df["Last_Name"]=df["Last_Name"].str.lstrip("...")
# df["Last_Name"]=df["Last_Name"].str.lstrip("/")
# df["Last_Name"]=df["Last_Name"].str.rstrip("_")
df["Last_Name"]=df["Last_Name"].str.strip("123./_")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Don        Snow  876-678-3469
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1012      Harry      Potter    7066950392
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017    Michael       Scott  123-643-9775
# 11        1018      Clark        Kent    7066950392
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# 2                 123 Dragons Road               Y              N
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('|','-')
df["Phone_Number"]=df["Phone_Number"].str.replace('/','-')
df["Phone_Number"]=df["Phone_Number"].str.replace('N-a','')
df["Phone_Number"]=df["Phone_Number"].str.replace('--','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Don        Snow  876-678-3469
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1012      Harry      Potter    7066950392
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017    Michael       Scott  123-643-9775
# 11        1018      Clark        Kent    7066950392
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# 2                 123 Dragons Road               Y              N
# ...

# %%
df[["Street Address","State"]]=df["Address"].str.split(",",expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Don        Snow  876-678-3469
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1012      Harry      Potter    7066950392
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017    Michael       Scott  123-643-9775
# 11        1018      Clark        Kent    7066950392
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# 2                 123 Dragons Road               Y              N
# ...

# %%
df["Address"]=df["Address"].str.replace("N/a","")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# ...

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer']=df['Paying Customer'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# ...

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# ...

# %%
# df=df.replace('N/a','')
# df=df.replace('NaN',"")
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent    7066950392
# ...

# %%
for x in df.index:
  if df.loc[x,"Do_Not_Contact"] == 'Y':
     df.drop(x,inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White    7066950392
# 4         1005        Don        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent    7066950392
# 18        1019      Creed      Braton
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire               Y              N
# ...

# %%
for x in df.index:
  if df.loc[x,"Phone_Number"] == '':
     df.drop(x,inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White    7066950392
# 4         1005        Don        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent    7066950392
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N
# 4                 123 Dragons Road               Y              N
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Don        Snow  876-678-3469
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1012      Harry      Potter    7066950392
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017    Michael       Scott  123-643-9775
# 11        1018      Clark        Kent    7066950392
#
#                            Address Paying Customer Do_Not_Contact
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N
# 2                 123 Dragons Road               Y              N
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Don        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# ...
